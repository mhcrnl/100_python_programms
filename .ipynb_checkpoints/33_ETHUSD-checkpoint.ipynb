# %% [markdown]
# <a href="https://colab.research.google.com/github/mhcrnl/100_python_programms/blob/master/33_ETHUSD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade mplfinance
# Instalarea librariilor necesare
# Out:
# Requirement already up-to-date: mplfinance in /usr/local/lib/python3.6/dist-packages (0.12.4a0)
# ...

# %%
# 1. Importarea librariilor
import pandas_datareader as pdr
import datetime
import mplfinance as mpf
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
# 2. Preluarea datelor online
stock = 'ETHUSD=X'
start = datetime.datetime(2019, 1, 1)
end = datetime.date.today()

df = pdr.get_data_yahoo(stock, start, end)
df.tail
# Out:
# <bound method NDFrame.tail of                   High         Low        Open       Close  Volume   Adj Close
# Date
# 2019-01-01  132.650711  141.397507  133.418152  140.819412     0.0  140.819412
# 2019-01-02  140.650955  156.929123  141.519516  155.047668     0.0  155.047668
# 2019-01-03  147.198364  155.863052  155.196030  149.135010     0.0  149.135010
# 2019-01-04  147.907104  156.878967  148.912888  154.581940     0.0  154.581940
# 2019-01-07  151.150711  158.450439  157.809494  151.699219     0.0  151.699219
# ...                ...         ...         ...         ...     ...         ...
# 2020-04-23  185.222107  190.210388  185.222107  189.236938     0.0  189.236938
# 2020-04-26  193.454163  199.552795  197.475723  197.224716     0.0  197.224716
# 2020-04-27  194.849426  198.786560  197.273499  198.415390     0.0  198.415390
# 2020-04-28  198.124512  218.454620  198.465195  216.968231     0.0  216.968231
# ...

# %%
mpf.plot(df, type='candle')

# %%
fix, ax = plt.subplots(figsize=(12,8))
ax = plt.plot(df['Close'], label='Pretul la inchidere')
plt.title("Crypto ETHER vs USD")
plt.ylabel("Pretul in USD")
# Out:
# Text(0, 0.5, 'Pretul in USD')

# %%
mpf.plot(df)

# %%
df.shape
# Out:
# (348, 6)

# %%
df.tail(5)
# Out:
#                   High         Low        Open       Close  Volume   Adj Close
# Date
# 2020-04-23  185.222107  190.210388  185.222107  189.236938     0.0  189.236938
# 2020-04-26  193.454163  199.552795  197.475723  197.224716     0.0  197.224716
# 2020-04-27  194.849426  198.786560  197.273499  198.415390     0.0  198.415390
# 2020-04-28  198.124512  218.454620  198.465195  216.968231     0.0  216.968231
# 2020-05-01  213.620316  208.211502  207.602051  213.620316     0.0  213.620316

# %%
df.head(5)
# Out:
#                   High         Low        Open       Close  Volume   Adj Close
# Date
# 2019-01-01  132.650711  141.397507  133.418152  140.819412     0.0  140.819412
# 2019-01-02  140.650955  156.929123  141.519516  155.047668     0.0  155.047668
# 2019-01-03  147.198364  155.863052  155.196030  149.135010     0.0  149.135010
# 2019-01-04  147.907104  156.878967  148.912888  154.581940     0.0  154.581940
# 2019-01-07  151.150711  158.450439  157.809494  151.699219     0.0  151.699219

# %%
mpf.plot(df, type='renko')

# %%
mpf.plot(df, type='pnf')

# %%
mpf.plot(df, type='ohlc', mav=4)

# %%
mpf.plot(df, type='candle', mav=(3,6,9))

# %%
mpf.plot(df, type='candle', mav=(3,6,9), volume=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/mplfinance/plotting.py:426: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax2.set_ylim( miny, maxy )
