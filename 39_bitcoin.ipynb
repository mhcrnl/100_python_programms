# %% [markdown]
# ## Cryptocurrency Analysis
# ### Bitcoin (BTC)

# %%
# This allows multiple outputs from a single jupyter notebook cell:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# !pip install --upgrade mplfinance
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/3b/a7/d74985c7e3143d285c6df9d611b93d1da3d6889320a8af135b0170fd90d8/mplfinance-0.12.4a0-py3-none-any.whl
# ...
#   Found existing installation: mplfinance 0.12.3a3
#     Uninstalling mplfinance-0.12.3a3:
#       Successfully uninstalled mplfinance-0.12.3a3
# ...

# %%
from sklearn import cluster
import pandas
import yfinance as yf 
import pandas_datareader as pdr
import datetime
import mplfinance as mpf
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# 1. Descarcarea datelor de pe yahoo [BTC-USD](https://finance.yahoo.com/quote/BTC-USD?p=BTC-USD)
# 2. Incarcarea datelor

# %%
stock = 'BTC-USD'
start = datetime.datetime(2020, 1, 1)
end = datetime.date.today()

df = pdr.get_data_yahoo(stock, start, end)
df.tail()
# Out:
#                    High          Low         Open        Close        Volume  \
# Date
# 2020-04-27  7814.527344  7730.806641  7796.970215  7807.058594  3.318796e+10
# 2020-04-28  8871.753906  7786.049316  7806.712402  8801.038086  6.020105e+10
# 2020-04-29  9440.650391  8533.255859  8797.669922  8658.553711  6.696463e+10
# 2020-04-30  9048.023438  8667.763672  8672.782227  8864.766602  4.406839e+10
# 2020-05-03  9164.205078  8974.866211  8988.734375  9157.320312  4.430236e+10
#
#               Adj Close
# Date
# 2020-04-27  7807.058594
# 2020-04-28  8801.038086
# 2020-04-29  8658.553711
# 2020-04-30  8864.766602
# 2020-05-03  9157.320312

# %%
df.head()
# Out:
#                    High          Low         Open        Close        Volume  \
# Date
# 2020-01-01  7254.330566  7174.944336  7194.892090  7200.174316  1.856566e+10
# 2020-01-02  7212.155273  6935.270020  7202.551270  6985.470215  2.080208e+10
# 2020-01-03  7413.715332  6914.996094  6984.428711  7344.884277  2.811148e+10
# 2020-01-04  7427.385742  7309.514160  7345.375488  7410.656738  1.844427e+10
# 2020-01-05  7544.497070  7400.535645  7410.451660  7411.317383  1.972507e+10
#
#               Adj Close
# Date
# 2020-01-01  7200.174316
# 2020-01-02  6985.470215
# 2020-01-03  7344.884277
# 2020-01-04  7410.656738
# 2020-01-05  7411.317383

# %%
fix, ax = plt.subplots(figsize=(14,8))
ax = plt.plot(df['Close'], label='Pretul la inchidere.')
plt.title('Crypto Bitcoin vs USD.')
plt.ylabel("Pretul in USD.")
# Out:
# Text(0, 0.5, 'Pretul in USD.')

# %%
mpf.plot(df, type='candle', figratio=(16,8), style='charles')

# %%
mpf.plot(df, type='ohlc')

# %%
mpf.plot(df, type='ohlc', mav=6)

# %%
mpf.plot(df, type='candle', mav=(3, 6, 9))

# %%
mpf.plot(df, type='candle', mav=(3, 6, 9), volume=True)

# %%
#df.index.name = 'Date'
#mpf.plot(df, hlines=[5000, 8000])
import yfinance as yf
